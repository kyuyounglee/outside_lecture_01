# %%
# %pip install yfinance

# %%
import yfinance as yf

company = yf.Ticker('NVDA')
company.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
basic_info = {
    "회사명": company.info.get("longName"),
    "산업": company.info.get("industry"),
    "부문": company.info.get("sector"),
    "시가총액": company.info.get("marketCap"),
    "총 발행 주식 수": company.info.get("sharesOutstanding"),
    "본사 위치": company.info.get("country"),
    "웹사이트": company.info.get("website")
}

basic_info
# Out:
# {'회사명': 'NVIDIA Corporation',
#  '산업': 'Semiconductors',
#  '부문': 'Technology',
#  '시가총액': 3201847787520,
#  '총 발행 주식 수': 24387600384,
#  '본사 위치': 'United States',
#  '웹사이트': 'https://www.nvidia.com'}

# %%
income_statement = company.financials
income_statement
# Out:
#                                                         2025-01-31  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.133
# Normalized EBITDA                                    86137000000.0
# Total Unusual Items                                            0.0
# Total Unusual Items Excluding Goodwill                         0.0
# Net Income From Continuing Operation Net Minori...   72880000000.0
# Reconciled Depreciation                               1864000000.0
# Reconciled Cost Of Revenue                           32639000000.0
# EBITDA                                               86137000000.0
# EBIT                                                 84273000000.0
# Net Interest Income                                   1539000000.0
# Interest Expense                                       247000000.0
# Interest Income                                       1786000000.0
# ...

# %%
balance_sheet = company.balance_sheet
balance_sheet
# Out:
#                                                      2025-01-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                            24477000000.0
# Share Issued                                      24477000000.0
# Net Debt                                                    NaN
# Total Debt                                        10270000000.0
# ...                                                         ...
# Allowance For Doubtful Accounts Receivable                  NaN
# Gross Accounts Receivable                                   NaN
# Cash Cash Equivalents And Short Term Investments  43210000000.0
# Other Short Term Investments                      34621000000.0
# Cash And Cash Equivalents                          8589000000.0
#
#                                                      2024-01-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                            24640000000.0
# ...

# %%
cash_flow = company.cash_flow
cash_flow
# Out:
#                                                    2025-01-31     2024-01-31  \
# Free Cash Flow                                  60853000000.0  27021000000.0
# Repurchase Of Capital Stock                    -33706000000.0  -9533000000.0
# Repayment Of Debt                               -1250000000.0  -1250000000.0
# Issuance Of Debt                                          NaN            0.0
# Capital Expenditure                             -3236000000.0  -1069000000.0
# Interest Paid Supplemental Data                   246000000.0    252000000.0
# Income Tax Paid Supplemental Data               15118000000.0   6549000000.0
# End Cash Position                                8589000000.0   7280000000.0
# Beginning Cash Position                          7280000000.0   3389000000.0
# Changes In Cash                                  1309000000.0   3891000000.0
# Financing Cash Flow                            -42359000000.0 -13633000000.0
# ...

# %%
pe_ratio = company.info.get('forwardPE')
pb_ratio = company.info.get('priceToBook')
eps = company.info.get('trailingEps')
roe = company.info.get('returnOnEquity')
current_volume = company.info.get('volume')

# %%
current_volume
# Out:
# 197101531

# %%
historical_data = company.history(period="1mo")
historical_data['Volume']
# Out:
# Date
# 2025-04-24 00:00:00-04:00    220815000
# 2025-04-25 00:00:00-04:00    251064700
# 2025-04-28 00:00:00-04:00    207708500
# 2025-04-29 00:00:00-04:00    170444300
# 2025-04-30 00:00:00-04:00    235044600
# 2025-05-01 00:00:00-04:00    236121500
# 2025-05-02 00:00:00-04:00    190194800
# 2025-05-05 00:00:00-04:00    133163200
# 2025-05-06 00:00:00-04:00    158525600
# 2025-05-07 00:00:00-04:00    206758800
# 2025-05-08 00:00:00-04:00    198428100
# 2025-05-09 00:00:00-04:00    132972200
# 2025-05-12 00:00:00-04:00    225023300
# 2025-05-13 00:00:00-04:00    330430100
# 2025-05-14 00:00:00-04:00    281180800
# 2025-05-15 00:00:00-04:00    226632600
# 2025-05-16 00:00:00-04:00    226542500
# 2025-05-19 00:00:00-04:00    193154600
# 2025-05-20 00:00:00-04:00    161514200
# 2025-05-21 00:00:00-04:00    270608700
# 2025-05-22 00:00:00-04:00    187344000
# 2025-05-23 00:00:00-04:00    198367700
# Name: Volume, dtype: int64

# %%
import pandas as pd

pd.DataFrame.from_dict(company.info, orient="index", columns=["Values"])
# Out:
#                                           Values
# address1               2788 San Tomas Expressway
# city                                 Santa Clara
# state                                         CA
# zip                                        95051
# country                            United States
# ...                                          ...
# gmtOffSetMilliseconds                  -14400000
# market                                 us_market
# esgPopulated                               False
# displayName                               NVIDIA
# trailingPegRatio                          1.8804
#
# [182 rows x 1 columns]
